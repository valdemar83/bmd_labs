# %%
import pandas as pd

# %%
path = "/Users/VLADIMIR/Downloads/cars.csv"
data = pd.read_csv(path, encoding = 'utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os
print ("The directory we are working in is:{}".format(os.getcwd()))
# Out:
# The directory we are working in is:C:\Users\VLADIMIR

# %%
data = pd.read_csv('cars.csv')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
data.shape
# Out:
# (38531, 30)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
# ...

# %%
data['color'].describe()
# Out:
# count     38531
# unique       12
# top       black
# freq       7705
# Name: color, dtype: object

# %%
cut_data = data.iloc[0:10, :]
cut_data
# Out:
#   manufacturer_name model_name transmission   color  odometer_value  \
# 0            Subaru    Outback    automatic  silver          190000
# 1            Subaru    Outback    automatic    blue          290000
# 2            Subaru   Forester    automatic     red          402000
# 3            Subaru    Impreza   mechanical    blue           10000
# 4            Subaru     Legacy    automatic   black          280000
# 5            Subaru    Outback    automatic  silver          132449
# 6            Subaru   Forester    automatic   black          318280
# 7            Subaru     Legacy    automatic  silver          350000
# 8            Subaru    Outback    automatic    grey          179000
# 9            Subaru   Forester    automatic  silver          571317
#
#    year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# 0           2010    gasoline           False    gasoline              2.5
# ...

# %%
new_data = ['used', 'used', 'new', 'new', 'used', 'used', 'used', 'used', 'used', 'used']
cut_data.insert(1, 'New', new_data)
cut_data
# Out:
#   manufacturer_name   New model_name transmission   color  odometer_value  \
# 0            Subaru  used    Outback    automatic  silver          190000
# 1            Subaru  used    Outback    automatic    blue          290000
# 2            Subaru   new   Forester    automatic     red          402000
# 3            Subaru   new    Impreza   mechanical    blue           10000
# 4            Subaru  used     Legacy    automatic   black          280000
# 5            Subaru  used    Outback    automatic  silver          132449
# 6            Subaru  used   Forester    automatic   black          318280
# 7            Subaru  used     Legacy    automatic  silver          350000
# 8            Subaru  used    Outback    automatic    grey          179000
# 9            Subaru  used   Forester    automatic  silver          571317
#
#    year_produced engine_fuel  engine_has_gas engine_type  ...  feature_1  \
# 0           2010    gasoline           False    gasoline  ...       True
# ...

# %%
cut_data.groupby('New').describe()
# Out:
#      odometer_value                                                          \
#               count       mean            std       min       25%       50%
# New
# new             2.0  206000.00  277185.858225   10000.0  108000.0  206000.0
# used            8.0  288880.75  136681.229104  132449.0  187250.0  285000.0
#
#                          year_produced            ... up_counter         \
#            75%       max         count      mean  ...        75%    max
# New                                               ...
# new   304000.0  402000.0           2.0  2000.000  ...       64.5   72.0
# used  326210.0  571317.0           8.0  2004.375  ...       54.5  147.0
#
#      duration_listed
#                count     mean        std   min     25%    50%     75%    max
# New
# new              2.0  118.500  45.961941  86.0  102.25  118.5  134.75  151.0
# used             8.0   85.375  94.391188   7.0   36.25   70.0   84.00  307.0
#
# [2 rows x 56 columns]
