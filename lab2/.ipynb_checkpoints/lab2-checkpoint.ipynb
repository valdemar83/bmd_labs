# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y=x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.1, 0.5, 0.4, 0.3])

axes1.plot(x,y, 'r')
axes1.set_xlabel('X Label')
axes1.set_ylabel('Y Label')
axes1.set_title('Title')

axes2.plot(y,x, 'b')
axes2.set_xlabel('X Label')
axes2.set_ylabel('Y Label')
axes2.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots()

axes.plot(x,y, 'r')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig, axes = plt.subplots(nrows=4, ncols=4)

plt.tight_layout()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, color="b")
ax.plot(x, x**3, color="g")

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, lw=2, ls='--')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, marker = 'o', markersize = 10, markerfacecolor='y')

# %%
fig.savefig('plot.png')

# %%
plt.scatter(x,y)

# %%
from random import sample

data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10.,  8.,  9., 10., 14., 13., 10., 10.,  6., 10.]),
#  array([ 16. , 113.8, 211.6, 309.4, 407.2, 505. , 602.8, 700.6, 798.4,
#         896.2, 994. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x9d5e188>,
#   <matplotlib.lines.Line2D at 0x9d5ebc8>,
#   <matplotlib.lines.Line2D at 0x9d6d7c8>,
#   <matplotlib.lines.Line2D at 0x9d6df48>,
#   <matplotlib.lines.Line2D at 0x9d7ec88>,
#   <matplotlib.lines.Line2D at 0x9d7e748>],
#  'caps': [<matplotlib.lines.Line2D at 0x9d5ecc8>,
#   <matplotlib.lines.Line2D at 0x9d62b88>,
#   <matplotlib.lines.Line2D at 0x9d6dfc8>,
#   <matplotlib.lines.Line2D at 0x9d67988>,
#   <matplotlib.lines.Line2D at 0x9d83d48>,
#   <matplotlib.lines.Line2D at 0x9d83cc8>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x9d55a88>,
#   <matplotlib.patches.PathPatch at 0x9d67ac8>,
#   <matplotlib.patches.PathPatch at 0x9d77f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x9d62c88>,
#   <matplotlib.lines.Line2D at 0x9d73f88>,
#   <matplotlib.lines.Line2D at 0x9d86d08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x9d67b48>,
#   <matplotlib.lines.Line2D at 0x9d77f88>,
#   <matplotlib.lines.Line2D at 0x9d86e08>],
#  'means': []}
